# %% [markdown]
# <a href="https://colab.research.google.com/github/Masa-hue/Masa/blob/main/Copy_of_Dow_Jones_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
raw_data = pd.read_csv('dow_jones_index.csv')
raw_data.head()
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# ...

# %%
raw_data['days_to_next_dividend'].unique()
# Out:
# array([ 19,  12,   5,  97,  90,  83,  76,  69,  62,  55,  48,  82,  75,
#         68,  61,  54,  47,  40,  33,  26,  89,   4,  74,  67,  60,  53,
#         46,  39,  32,  25,  18,  11,  31,  24,  17,  10,   3,  28,  21,
#         14,   7,   0, 329, 322, 315, 308, 301, 294, 287, 280, 273, 266,
#        259, 118, 111, 104,  95,  88,  81,  59,  52,  45,  38,  87,  80,
#         84,  77,  70,  63,  56,  49,  42,  20,  13,   6,  35,  73,  66,
#         96,  23,  16,   9,   2,  41,  34,  27, 252, 245, 238, 232, 224,
#        217, 210, 203, 196, 189, 182, 175, 168,  15,  91,  71,  36])

# %%
raw_data['days_to_next_dividend'].nunique()
# Out:
# 103

# %%
raw_data['days_to_next_dividend'].value_counts()
# Out:
# 54     31
# 82     28
# 61     28
# 68     28
# 75     27
#        ..
# 111     1
# 104     1
# 23      1
# 16      1
# 36      1
# Name: days_to_next_dividend, Length: 103, dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   quarter                             750 non-null    int64
#  1   stock                               750 non-null    object
#  2   date                                750 non-null    object
#  3   open                                750 non-null    object
#  4   high                                750 non-null    object
#  5   low                                 750 non-null    object
#  6   close                               750 non-null    object
#  7   volume                              750 non-null    int64
#  8   percent_change_price                750 non-null    float64
#  9   percent_change_volume_over_last_wk  720 non-null    float64
#  10  previous_weeks_volume               720 non-null    float64
# ...

# %%
raw_data['volume'].mean()
# Out:
# 117547801.40666667

# %%
raw_data.columns
# Out:
# Index(['quarter', 'stock', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'percent_change_price', 'percent_change_volume_over_last_wk',
#        'previous_weeks_volume', 'next_weeks_open', 'next_weeks_close',
#        'percent_change_next_weeks_price', 'days_to_next_dividend',
#        'percent_return_next_dividend'],
#       dtype='object')

# %%
raw_data.dtypes
# Out:
# quarter                                 int64
# stock                                  object
# date                                   object
# open                                   object
# high                                   object
# low                                    object
# close                                  object
# volume                                  int64
# percent_change_price                  float64
# percent_change_volume_over_last_wk    float64
# previous_weeks_volume                 float64
# next_weeks_open                        object
# next_weeks_close                       object
# percent_change_next_weeks_price       float64
# days_to_next_dividend                   int64
# percent_return_next_dividend          float64
# dtype: object

# %%
raw_data.isnull().sum()
# Out:
# quarter                                0
# stock                                  0
# date                                   0
# open                                   0
# high                                   0
# low                                    0
# close                                  0
# volume                                 0
# percent_change_price                   0
# percent_change_volume_over_last_wk    30
# previous_weeks_volume                 30
# next_weeks_open                        0
# next_weeks_close                       0
# percent_change_next_weeks_price        0
# days_to_next_dividend                  0
# percent_return_next_dividend           0
# dtype: int64

# %%
raw_data = raw_data.dropna(axis=0)
raw_data.isnull().sum()
# Out:
# quarter                               0
# stock                                 0
# date                                  0
# open                                  0
# high                                  0
# low                                   0
# close                                 0
# volume                                0
# percent_change_price                  0
# percent_change_volume_over_last_wk    0
# previous_weeks_volume                 0
# next_weeks_open                       0
# next_weeks_close                      0
# percent_change_next_weeks_price       0
# days_to_next_dividend                 0
# percent_return_next_dividend          0
# dtype: int64

# %%
raw_data.groupby("volume").mean()
# Out:
# <ipython-input-14-b4d41da627cd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   raw_data.groupby("volume").mean()
#             quarter  percent_change_price  percent_change_volume_over_last_wk  \
# volume
# 9718851         2.0              2.153580                          -36.790058
# 10135730        2.0              3.371540                          -34.437948
# 10705548        1.0              1.650730                           -7.598549
# 11585909        1.0              2.800470                          -28.335711
# 11690792        2.0             -0.992295                          -28.339435
# ...             ...                   ...                                 ...
# 873241317       2.0             -3.398930                           46.413698
# ...

# %%
raw_data.min()
# Out:
# quarter                                       1
# stock                                        AA
# date                                  1/14/2011
# open                                     $10.59
# high                                     $10.94
# low                                      $10.40
# close                                    $10.52
# volume                                  9718851
# percent_change_price                   -15.4229
# percent_change_volume_over_last_wk   -61.433175
# previous_weeks_volume                 9718851.0
# next_weeks_open                          $10.52
# next_weeks_close                         $10.52
# percent_change_next_weeks_price        -15.4229
# days_to_next_dividend                         0
# percent_return_next_dividend           0.065574
# dtype: object

# %%
raw_data.max()
# Out:
# quarter                                          2
# stock                                          XOM
# date                                      6/3/2011
# open                                        $99.62
# high                                        $99.72
# low                                         $99.61
# close                                       $99.93
# volume                                  1054415375
# percent_change_price                       9.88223
# percent_change_volume_over_last_wk      327.408924
# previous_weeks_volume                 1453438639.0
# next_weeks_open                             $99.96
# next_weeks_close                            $99.93
# percent_change_next_weeks_price            9.88223
# days_to_next_dividend                          329
# percent_return_next_dividend               1.56421
# dtype: object

# %%
raw_data.describe()
# Out:
#           quarter        volume  percent_change_price  \
# count  720.000000  7.200000e+02            720.000000
# mean     1.541667  1.156040e+08              0.030140
# std      0.498607  1.520844e+08              2.504889
# min      1.000000  9.718851e+06            -15.422900
# 25%      1.000000  3.069225e+07             -1.297355
# 50%      2.000000  5.274535e+07              0.000000
# 75%      2.000000  1.311530e+08              1.630870
# max      2.000000  1.054415e+09              9.882230
#
#        percent_change_volume_over_last_wk  previous_weeks_volume  \
# count                          720.000000           7.200000e+02
# mean                             5.593627           1.173876e+08
# std                             40.543478           1.592322e+08
# min                            -61.433175           9.718851e+06
# 25%                            -19.804284           3.067832e+07
# 50%                              0.512586           5.294556e+07
# ...

# %%
sns.distplot(raw_data['volume'])
# Out:
# <ipython-input-18-e760cd779132>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(raw_data['volume'])
# <Axes: xlabel='volume', ylabel='Density'>

# %%
sns.heatmap(raw_data.corr(), cbar= True, linewidths=0.5)
# Out:
# <ipython-input-19-91ea10ac8ec8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(raw_data.corr(), cbar= True, linewidths=0.5)
# <Axes: >

# %%
plt.hist(raw_data["volume"])
# Out:
# (array([514.,  90.,  64.,  15.,  13.,   9.,   5.,   5.,   2.,   3.]),
#  array([9.71885100e+06, 1.14188503e+08, 2.18658156e+08, 3.23127808e+08,
#         4.27597461e+08, 5.32067113e+08, 6.36536765e+08, 7.41006418e+08,
#         8.45476070e+08, 9.49945723e+08, 1.05441538e+09]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(raw_data[raw_data["days_to_next_dividend"] >100]["days_to_next_dividend"])
# Out:
# (array([3., 0., 1., 3., 3., 4., 3., 3., 3., 4.]),
#  array([104. , 126.5, 149. , 171.5, 194. , 216.5, 239. , 261.5, 284. ,
#         306.5, 329. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(raw_data["days_to_next_dividend"], raw_data["days_to_next_dividend"])
# Out:
# <BarContainer object of 720 artists>

# %%
volume=np.array(raw_data["volume"] [10:15])
days_to_next_dividend=np.array(raw_data["days_to_next_dividend"][10:15])
# kreira nizove od do indexa
plt.bar(volume,days_to_next_dividend)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(volume,days_to_next_dividend, color = "Green")

# %%
bar_plot = sns.barplot(x = raw_data ["volume"][:10], y =raw_data["days_to_next_dividend"][:10], palette= "Blues")
plt.show()

# %%
sns.displot(raw_data.days_to_next_dividend, bins =200)

# %%
sns.pairplot(raw_data[:100], hue="days_to_next_dividend", palette="Set2")

# %%
sns.scatterplot(x="volume", y = "percent_change_price", data = raw_data[:100], hue="days_to_next_dividend", size="days_to_next_dividend")
# Out:
# <Axes: xlabel='volume', ylabel='percent_change_price'>

# %%
sns.scatterplot(x="volume", y = "price", data = raw_data[:100], hue="days_to_next_dividend", size="days_to_next_dividend")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3974b297374c> in <cell line: 1>()
# ----> 1 sns.scatterplot(x="volume", y = "price", data = raw_data[:100], hue="days_to_next_dividend", size="days_to_next_dividend")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# ...
