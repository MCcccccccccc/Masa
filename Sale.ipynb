# %% [markdown]
# <a href="https://colab.research.google.com/github/Masa-hue/Masa/blob/main/Sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# prvo importovati i pokrenuti pande, seaborn, pyplot, matplat, heatplot isl

# %%
raw_data = pd.read_csv('sale.csv')
raw_data.head()
# read učitava i head prikazuje prvih 5 redova 
# read učita importovane podatke - read data (imported data from downloaded files: Upload to session storage)
# kad su okrugle zagrade () radi se o izvšenju aktivnosti, a sa [] obiljezavamo varijablu
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
raw_data['Milk'].unique()
# prikazuje vrijednosti za pojedini atribut/kolonu []
# Out:
# array([ 9656,  9810,  8808,  1196,  5410,  8259,  3199,  4956,  3648,
#        11093,  5403,  1124, 12319,  6208,  9465,  1114,  8816,  6157,
#         6327,  2495,  4519,   871,  1917, 36423,  9776,  4230,   961,
#          803, 20484,  2100,  3610,  4339,  1318,  4786,  1979,  5491,
#         4362, 10556, 15729,   555,  4332,  3065,  7555, 11095,  7027,
#        22044, 14069, 54259,  6152, 21412,  1095,  4051,  3916, 10473,
#         1449,  3683, 29892,  9933,  1970,  5360,  3045, 38369,  6245,
#        11601,  1227, 20959,  1534,  6759,  7260,  2820,  2037,  1266,
#         5139,  5332,  6343,  1137,  3587, 12697,  1175,  3259,   829,
#         9540,  9232,  1563,  3327, 46197, 73498,  5025,   542,  3836,
#          596,  2762, 27472,  3090, 12220,  2920,  2616,   254,   112,
#         2182,  7779, 10810,  6459,  3504,  2132,  1014,  6337, 10646,
#         8397, 16729,  1648, 11114,  2770,  2295,  1080,   793,  2521,
# ...

# %%
raw_data['Milk'].nunique()
# prikazuje broj unosa za pojedini atribut/kolonu
# Out:
# 421

# %%
raw_data['Milk'].value_counts()
# prikazuje koje i koliko se pojavljuje vrijednosti za pojedini atribut[]
# Out:
# 3045     2
# 1610     2
# 5139     2
# 2428     2
# 3587     2
#         ..
# 1596     1
# 7152     1
# 13252    1
# 4280     1
# 1698     1
# Name: Milk, Length: 421, dtype: int64

# %%
 raw_data.info()
 # info o non-null poljima, vrsti podataka (int - broj, str - text, object - slika i dr.) i veličini (memoriji)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
raw_data[raw_data['Milk']==8808]
# pronalazi iz database traženi atribut [] zadate vrijednosti ==
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 2        2       3   6353  8808     7684    2405              3516        7844

# %%
raw_data=raw_data.rename(columns = {'Delicassen' : 'Delicates'})
raw_data.head()
# rename nazivi kolene i iscita prvih 5 da provjerimo
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicates
# 0        2       3  12669  9656     7561     214              2674       1338
# 1        2       3   7057  9810     9568    1762              3293       1776
# 2        2       3   6353  8808     7684    2405              3516       7844
# 3        1       3  13265  1196     4221    6404               507       1788
# 4        2       3  22615  5410     7198    3915              1777       5185

# %%
raw_data['Milk'].mean()
# daje provjecnu vrijednost pojedinačnog atributa/kolene []
# Out:
# 5796.265909090909

# %%
raw_data.shape
#(broj redova, broj kolona)
# Out:
# (440, 8)

# %%
raw_data.index
#početni index, krajnji i razmak
# Out:
# RangeIndex(start=0, stop=440, step=1)

# %%
raw_data.columns
#nazivi kolana
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
raw_data.dtypes
# daje info o tipu podataka: int -cijeli broj, float - decimalni, object - tekst, datum isl
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
raw_data["Region"]. unique()
# daje različite vrijednosti kolone, nunique - daje broj različitih vrijednosti kolone
# Out:
# array([3, 1, 2])

# %%
raw_data["Region"]. nunique()
# Out:
# 3

# %%
raw_data.isnull().sum()
# isnull daje broj vrijednosti koje su nepopunjene, prazne tj nula
#notnull broj popunjenih koje nisu prazne vrijednosti
# da smo imali praznih redova ako je <5% mogu se izbrisati preko rawdata.dropnal ili column()
# ako je >5% mogu se zamjenili bi sa prosječnom vrijednosti

# raw_data['Milk']=raw_data['Milk'].fillna(price_mean)
## raw_data = raw_data.dropna(axis=0)
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
raw_data.notnull().sum()
# notnull = koliko redova nije prazna
# Out:
# Channel             440
# Region              440
# Fresh               440
# Milk                440
# Grocery             440
# Frozen              440
# Detergents_Paper    440
# Delicassen          440
# dtype: int64

# %%
raw_data.count()
# koliko svaka kolona (atribut) ima redova
# Out:
# Channel             440
# Region              440
# Fresh               440
# Milk                440
# Grocery             440
# Frozen              440
# Detergents_Paper    440
# Delicassen          440
# dtype: int64

# %%
raw_data["Milk"].value_counts()
# koliko i koje različite vrijednosti imamo u koloni na pr. Milk
# Out:
# 3045     2
# 1610     2
# 5139     2
# 2428     2
# 3587     2
#         ..
# 1596     1
# 7152     1
# 13252    1
# 4280     1
# 1698     1
# Name: Milk, Length: 421, dtype: int64

# %%
raw_data[raw_data["Milk"]==3045]
# koliko puta i gdje je milijeko bilo 3045
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 60         2       3   8590  3045     7854      96              4095
# 273        1       3  36817  3045     1493    4802               210
#
#      Delicassen
# 60          225
# 273        1824

# %%
raw_data.groupby("Milk").get_group(3045)

# gropuby - grupisanje po nekom atributi/koloni isl.
# get_group - izvući grupu po zadatom parametru
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 60         2       3   8590  3045     7854      96              4095
# 273        1       3  36817  3045     1493    4802               210
#
#      Delicassen
# 60          225
# 273        1824

# %%
raw_data.rename(columns= {"Region": "region", "Delicassen": "Delikates"}   )
# mijenja nazive vieše kolona
# Out:
#      Channel  region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delikates
# 0         1338
# 1         1776
# 2         7844
# 3         1788
# 4         5185
# ..         ...
# ...

# %%
raw_data.head(3)
#prikazuje prva 3 reda isl 2,3,itd...
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844

# %%
raw_data.groupby("Milk").mean()
# grupirano po Milk i date srednje vrijednosti ostalih 7 kolona
# Out:
#        Channel  Region    Fresh  Grocery   Frozen  Detergents_Paper  \
# Milk
# 55         1.0     3.0    622.0    137.0     75.0               7.0
# 112        1.0     3.0    503.0    778.0    895.0              56.0
# 134        1.0     3.0  22686.0    218.0   3157.0               9.0
# 201        1.0     3.0  12212.0    245.0   1991.0              25.0
# 254        1.0     3.0    403.0    610.0    774.0              54.0
# ...        ...     ...      ...      ...      ...               ...
# 38369      2.0     3.0  35942.0  59598.0   3254.0           26701.0
# 43950      1.0     3.0  36847.0  20170.0  36534.0             239.0
# 46197      2.0     3.0  16117.0  92780.0   1026.0           40827.0
# 54259      2.0     3.0  44466.0  55571.0   7782.0           24171.0
# 73498      2.0     3.0  22925.0  32114.0    987.0           20070.0
#
#        Delicassen
# Milk
# 55            8.0
# 112         132.0
# 134         548.0
# 201         860.0
# 254          63.0
# ...           ...
# ...

# %%
raw_data[raw_data["Milk"]==55]
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 154        1       3    622    55      137      75                 7
#
#      Delicassen
# 154           8

# %%
raw_data.min()
# min vrijednosti po kolonama
# Out:
# Channel              1
# Region               1
# Fresh                3
# Milk                55
# Grocery              3
# Frozen              25
# Detergents_Paper     3
# Delicassen           3
# dtype: int64

# %%
raw_data.max()
# max vrijednosti
# Out:
# Channel                  2
# Region                   3
# Fresh               112151
# Milk                 73498
# Grocery              92780
# Frozen               60869
# Detergents_Paper     40827
# Delicassen           47943
# dtype: int64

# %%
raw_data.describe()
# daje broj vrijednosti (redova), mean - prosjećna vrijednost, std - standard devioation, min, 25%, 50% - medijana, 75%, max
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
raw_data[(raw_data['Milk'][:10]>440) & (raw_data['Milk']==55)]

# objasniti
# Out:
# Empty DataFrame
# Columns: [Channel, Region, Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen]
# Index: []

# %%
sns.distplot(raw_data['Milk'])
# distribicija podataka
# Out:
# <ipython-input-44-2fbe80b86d6b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(raw_data['Milk'])
# <Axes: xlabel='Milk', ylabel='Density'>

# %%
q = raw_data['Milk'].quantile(0.99) 
data_1 = raw_data[raw_data['Milk']<q]
data_1.describe(include='all')
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  435.000000  435.000000     435.000000    435.000000    435.000000
# mean     1.317241    2.537931   11778.928736   5273.756322   7444.434483
# std      0.465938    0.777157   12500.508229   5412.156142   7839.154951
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3100.000000   1520.500000   2146.500000
# 50%      1.000000    3.000000    8258.000000   3610.000000   4740.000000
# 75%      2.000000    3.000000   16718.000000   7086.000000  10431.000000
# max      2.000000    3.000000  112151.000000  36423.000000  67298.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    435.000000        435.000000    435.000000
# mean    2993.257471       2657.124138   1403.841379
# std     4602.427321       4071.577286   1732.917635
# min       25.000000          3.000000      3.000000
# ...

# %%
sns.distplot(raw_data['Milk'])
# distribucija nakon skraćivanja niza sa velikim oscilacijama kako bi se uočio patern
# Out:
# <ipython-input-80-2fbe80b86d6b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(raw_data['Milk'])
# <Axes: xlabel='Milk', ylabel='Density'>

# %%
sns.heatmap(raw_data.corr(), cbar= True, linewidths=0.5)

# heatmap - odnos izmedu varijabli svake sa svakom prikazuje da što je veća korelacija boja je svjetlija, +/- znači direktno ili obrnuto proporcionalno
# Out:
# <Axes: >

# %%
plt.hist(raw_data["Milk"])
plt.show()

# prikazuje histogram

# %%
plt.hist(raw_data[raw_data["Milk"] >20000]["Milk"])
plt.show()
# prikazuje histogram samo za vrijednosti veće od zadate  na pr. 20.000

# %%
plt.bar(raw_data["Milk"], raw_data["Fresh"])
plt.show()

# plt.bar() - bar graf sa 2 varijable

# %%
Milk=np.array(raw_data["Milk"] [10:15])
Fresh=np.array(raw_data["Fresh"][10:15])
# kreira nizove od do indexa
plt.bar(Milk,Fresh, color = "Green")

#Kreira bar graf sa dvije varijable, ali ne sve podatke nego samo zadate po indexima na pr prvih [:10] ili od-do [10:20]
# Out:
# <BarContainer object of 5 artists>

# %%
Milk=np.array(raw_data["Milk"] [10:15])
Fresh=np.array(raw_data["Fresh"][10:15])
# kreira nizove od do indexa
plt.plot(Milk,Fresh, color = "Green")
# plt.plot() - kreira graf i zadaje boju

# %%
Region=np.array(raw_data["Region"][10:15])
plt.subplot(1,2,1)
plt.xlabel("Milk")
plt.ylabel("Fresh")
plt.title("Milk vs Fresh")
plt.plot(Milk,Fresh)

plt.subplot(1,2,2)
plt.plot(Milk,Region)
plt.xlabel("Milk")
plt.ylabel("Region")
plt.title("Milk vs Region")

plt.show()

# =np.array() kreira niz od podataka sa zadatim indexima od-do
# subplot () prikazuje dva grafa

# %%
bar_plot = sns.barplot(x = raw_data ["Milk"][:10], y =raw_data["Fresh"][:10], palette= "Blues")
plt.show()

# %%
sns.displot(raw_data.Milk, bins =200)

# prikazuje distribuciju, bins - broj

# %%
sns.pairplot(raw_data[:100], hue="Fresh", palette="Set2")

# prikazuje vrijednosti posmatrane i zatade varijable # hue=

# %%
sns.scatterplot(x="Grocery", y = "Frozen", data = raw_data[:100], hue="Fresh", size="Fresh")
# u odnosu na 2 varijable prikazuje zadatu varijablu # hue= i njenu veličinu # size=
# Out:
# <Axes: xlabel='Grocery', ylabel='Frozen'>

# %%
sns.boxlot(x= "Milk", y = "Region", data = raw_data[:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-8fc702362cef> in <cell line: 1>()
# ----> 1 sns.boxlot(x= "Milk", y = "Region", data = raw_data[:10])
#
# AttributeError: module 'seaborn' has no attribute 'boxlot'

# %%
sns.distplot(raw_data['Milk'])

# Jedan od najboljih nacina za uocavanje patterna je preko PDF
#probability distribution function koja pokazuje raspored vrijednosti za odredjenu kolonu.
# Idealna raspodjela je normalna - isti broj (visina stubova) je sa lijeve i desne strane
# Out:
# <ipython-input-79-2fbe80b86d6b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(raw_data['Milk'])
# <Axes: xlabel='Milk', ylabel='Density'>

# %%
q = raw_data['Milk'].quantile(0.75) 
data1 = raw_data[raw_data['Milk']<q]
data1.describe(include='all')

# budući da je najviše na desnoj strani suziti ćemo koristenjem funkcije percentile
# koja prima parametar i vraca njegov postotak. Ukoliko napisemo

# q = quantile(0.25)
# dobicemo broj za koji vazi da je 25% dataseta ispod vrijednosti q (manje od q).
# Ukoliko imamo quantile(0.99) dobivamo broj za koji vazi da je 99% dataseta manje od tog broja

# Nakon primjene quantile metode mozemo primijetiti da je max sada dosta manji, prije je bio veći.
# Iako ovo i dalje nije idealna slika, dosta je bolja od prethodne i bliza normalnoj distribuciji u odnosu na prethodni slucaj
# Out:
#           Channel      Region         Fresh         Milk       Grocery  \
# count  330.000000  330.000000    330.000000   330.000000    330.000000
# mean     1.187879    2.548485  12497.736364  2886.384848   4813.781818
# std      0.391209    0.767351  12074.068091  1933.703983   5361.852456
# min      1.000000    1.000000      3.000000    55.000000      3.000000
# 25%      1.000000    2.000000   3488.000000  1197.000000   1903.750000
# 50%      1.000000    3.000000   9174.000000  2359.000000   3134.000000
# 75%      1.000000    3.000000  17499.500000  4250.250000   6500.750000
# max      2.000000    3.000000  76237.000000  7184.000000  67298.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    330.000000        330.000000    330.000000
# mean    3010.918182       1494.996970   1182.284848
# std     3767.273142       2934.789602   1440.995001
# min       25.000000          3.000000      3.000000
# 25%      810.500000        212.750000    379.000000
# ...

# %%
sns.distplot(data_1['Milk'])
# Out:
# <ipython-input-88-27a583979479>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Milk'])
# <Axes: xlabel='Milk', ylabel='Density'>

# %%
data_2 = data_1[data_1['Milk']<300]
data_2.head(10)

# #filtiracemo dataset tako da ukljuci samo vrijednosti koje su ispod 3000
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 97         1       3    403   254      610     774                54
# 98         1       3    503   112      778     895                56
# 122        1       3  12212   201      245    1991                25
# 154        1       3    622    55      137      75                 7
# 191        1       3  13624   295     1381     890                43
# 269        1       1  15218   258     1138    2516               333
# 289        1       3  42786   286      471    1388                32
# 356        1       3  22686   134      218    3157                 9
#
#      Delicassen
# 97           63
# 98          132
# 122         860
# 154           8
# 191          84
# 269         204
# 289          22
# 356         548

# %%
data_2.tail(3)
# prikazuje zadnja tri
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 269        1       1  15218   258     1138    2516               333
# 289        1       3  42786   286      471    1388                32
# 356        1       3  22686   134      218    3157                 9
#
#      Delicassen
# 269         204
# 289          22
# 356         548

# %%
data_2<=60
# prikazuje kad je <=60
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 97      True    True  False  False    False   False              True
# 98      True    True  False  False    False   False              True
# 122     True    True  False  False    False   False              True
# 154     True    True  False   True    False   False              True
# 191     True    True  False  False    False   False              True
# 269     True    True  False  False    False   False             False
# 289     True    True  False  False    False   False              True
# 356     True    True  False  False    False   False              True
#
#      Delicassen
# 97        False
# 98        False
# 122       False
# 154        True
# 191       False
# 269       False
# 289        True
# 356       False

# %%
sns.distplot(data_2)
# Out:
# <ipython-input-181-c2569d390ebc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2)
# <Axes: ylabel='Density'>

# %%
raw_data[(raw_data["Milk"]<60) & (raw_data["Milk"]==55)]
# prikazuje kad je < 60 i = 55
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 154        1       3    622    55      137      75                 7
#
#      Delicassen
# 154           8

# %%
Milk2=("Milk")
# uvođenje za ubacivanje nove kolone

# %%
raw_data=raw_data.drop("Milk", axis=1)
# drop izbacuje kolonu

# %%
raw_data.head()
# izbacena kolona Milk
# Out:
#    Channel  Region  Fresh  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669     7561     214              2674        1338
# 1        2       3   7057     9568    1762              3293        1776
# 2        2       3   6353     7684    2405              3516        7844
# 3        1       3  13265     4221    6404               507        1788
# 4        2       3  22615     7198    3915              1777        5185

# %%
raw_data.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Grocery', 'Frozen', 'Detergents_Paper',
#        'Delicassen'],
#       dtype='object')

# %%
raw_data["Milk_new"]=Milk2
#ubacivanje nove kolone
# nije iste dužine serija podataka dok je ova ista
#kako ubaciti vrijednosti?????????????

# %%
raw_data.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Grocery', 'Frozen', 'Detergents_Paper',
#        'Delicassen', 'Milk_new'],
#       dtype='object')

# %%
raw_data.head()
# Out:
#    Channel  Region  Fresh  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0        2       3  12669     7561     214              2674        1338
# 1        2       3   7057     9568    1762              3293        1776
# 2        2       3   6353     7684    2405              3516        7844
# 3        1       3  13265     4221    6404               507        1788
# 4        2       3  22615     7198    3915              1777        5185
#
#   Milk_new
# 0     Milk
# 1     Milk
# 2     Milk
# 3     Milk
# 4     Milk

# %%
raw_data.sort_values(by="Fresh")
# sortiranje tabele po koloni
# Out:
#      Channel  Region   Fresh  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 95         1       3       3     6252     440               223         709
# 338        1       2       3     7021   15601                15         550
# 66         1       3       9     7417     175              3468          27
# 218        2       1      18    15205    1285              4797        6372
# 96         2       3      23     8118     145              3874         217
# ..       ...     ...     ...      ...     ...               ...         ...
# 258        1       1   56083     2124    6422               730        3321
# 39         1       3   56159      902   10002               212        2916
# 284        1       3   68951    12609    8692               751        2406
# 125        1       3   76237     7102   16538               778         918
# 181        1       3  112151    18148   16745              4948        8550
#
#     Milk_new
# 95      Milk
# 338     Milk
# ...

# %%
raw_data.sort_values(by=["Fresh", "Frozen"], ascending=False)

# sortiranje po 2 kolone
# Out:
#      Channel  Region   Fresh  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 181        1       3  112151    18148   16745              4948        8550
# 125        1       3   76237     7102   16538               778         918
# 284        1       3   68951    12609    8692               751        2406
# 39         1       3   56159      902   10002               212        2916
# 258        1       1   56083     2124    6422               730        3321
# ..       ...     ...     ...      ...     ...               ...         ...
# 96         2       3      23     8118     145              3874         217
# 218        2       1      18    15205    1285              4797        6372
# 66         1       3       9     7417     175              3468          27
# 338        1       2       3     7021   15601                15         550
# 95         1       3       3     6252     440               223         709
#
#     Milk_new
# 181     Milk
# 125     Milk
# ...

# %%
raw_data[raw_data["Fresh"]==3]
# koje su redovi, region isl gdje je Fresh = 3
# Out:
#      Channel  Region  Fresh  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 95         1       3      3     6252     440               223         709
# 338        1       2      3     7021   15601                15         550
#
#     Milk_new
# 95      Milk
# 338     Milk

# %%
raw_data[raw_data['Fresh']==3]['Region']
# koje je Region za Fresh=3
# Out:
# 95     3
# 338    2
# Name: Region, dtype: int64

# %%
def fun (i):
  for i in raw_data:
    if i ==254:
        print (i)


        # šta ne valja na printa i????????????

# %%
int=[1,2,35,66,100,200,300,6]  
for i in int:
    if (i==100) & (1<=35):
      print(i)
    else: print ("nije manje ili jednako 100")

    # IF i petlje???
# Out:
# nije manje ili jednako 100
# nije manje ili jednako 100
# nije manje ili jednako 100
# nije manje ili jednako 100
# 100
# nije manje ili jednako 100
# nije manje ili jednako 100
# nije manje ili jednako 100

# %%
a,b,c = ("Orange", "Blue", "Green")
print(a,b,c)
# Out:
# Orange Blue Green

# %%
a=("Python je za:")
b=("=10")
print (a+b)

## LAB: Kreirati dvije varijable a i b.
# Varijablu a inicijalizirati sa "Python je za: ", a varijablu b inicijalizirati sa "10".
# Finalno kreirati varijablu c, koja je jednaka zbiru varijabli a i b. Na ekranu ispisati vrijednost varijable c.
# Out:
# Python je za:=10

# %%
x=5
x+=3

print(x)
# Out:
# 8

# %%
x=3
y=5
print(x==y)
print(x!=y)
print(x<=y)
print(x>=y)

# operatori za poređenje
# Out:
# False
# True
# True
# False

# %%
3 == 3.0
3.0 >= 3
3.0 != 3
4 * 0.5 != 2
2 ** 3 >= 7
7 % 4 <= 8 % 3
# Out:
# False

# %%
7 % 4 <= 8 % 3
# Out:
# False

# %%
str=("Hello")
print(str)
int=1,3,5
print(int)
type(str)
type(int)

#type je tip podataka int, str,
# Out:
# Hello
# (1, 3, 5)
# tuple

# %%
int=1,3,5
type(int)
x=("ime")
type(x)
# šta je type ili tuple??
# Out:
# str

# %%
#Boolean znači da rezultat može biti samo 1 od 2 moguća: True or False

# %%
def fun ():
  print ("hello")

# %%
fun()
# Out:
# hello

# %%
fun1("Masa")
fun1("Nezla")

# %%
def fun1(name):
  print ("hello " + name)
fun1("Masa")
fun1("Nezla")
# Out:
# hello Masa
# hello Nezla

# %%
a=5
b=6

# %%
def fun (broj1, broj2):
  broj3=broj1 + broj2
  print(broj3)

# %%
fun(a,b)
# Out:
# 11

# %%
def fun1 (a,b):
  if(a>b):
    print("Prvi broj je veci")
  else: print("Prvi broj nije veci")

# %%
fun1 (a,b)
# Out:
# Prvi broj nije veci
